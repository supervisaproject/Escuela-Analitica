# %% [markdown]
# # Ejemplo 4

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.4MB 3.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 512kB 31.4MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 112kB 3.4MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 174kB 3.4MB/s eta 0:00:01
# ...
#   Created wheel for openpyxl: filename=openpyxl-3.0.3-py2.py3-none-any.whl size=241261 sha256=9684160e749725e6cb8ed052aef7b2a8415346a90556346e9897bc43697562d7
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b5/85/ca/e768ac132e57e75e645a151f8badac71cc0089e7225dddf76b
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-cp37-none-any.whl size=8917 sha256=c0b37fb6de1a18b2cf2269c9afca1866c0d1318ccd0676f78915f24ce5aaeb9a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ##  1 Lectura y carga de datos

# %%
ls
# Out:
# 'Customer Churn Model.txt'   Untitled.ipynb
#  titanic3.xlsx               winequality_red_write.csv

# %%
wine_quality = pd.read_csv("winequality_red_write.csv", sep = '|')

# %%
wine_quality
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
customer = pd.read_csv("Customer Churn Model.txt", sep = ',')

# %%
customer
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
wine_quality.to_csv("wine_quality.csv", sep = ',')

# %%
titanic = pd.read_excel("titanic3.xlsx")

# %%
titanic.to_excel("new_titanic3.xlsx")
