# %% [markdown]
# # Ejemplo_1_limpieza

# %% [markdown]
# Los datos, en su forma natural (lo que llamamos “Raw Data”), suelen tener errores de registro que imposibilitan un análisis exacto. Al ser registrados por distintos sistemas y personas, es normal que terminemos con un fichero en el que un mismo valor esté expresado de distintas maneras (por ejemplo, una fecha puede estar registrada como 28 de Junio, o como 28/06 en una mismo archivo), pueden haber registros en blanco, números con coma en vez de punto, etc.
#
# Al momento de hacer un análisis de esos datos, todos esos registros tienen que pre-procesarse. Es decir, se tiene que limpiar, unificar, consolidar y normalizar los datos para que se puedan utilizar y lograr extraer información de valor (Data Wrangling).

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.4MB 3.5MB/s eta 0:00:01    |███                             | 983kB 3.5MB/s eta 0:00:03
# ...
#      |████████████████████████████████| 20.1MB 302kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 512kB 48.2MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv("./Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ## 1 Crear un subconjunto de datos

# %% [markdown]
# ### 1.1 Subconjunto de columna o columnas

# %%
account_length = data["Account Length"]

# %%
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.core.series.Series

# %%
subset = data[["Account Length", "Phone", "Eve Charge", "Day Calls"]]

# %%
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_columns = ["Account Length", "Phone", "Eve Charge", "Night Calls"]
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Night Calls
# 0             128  382-4657       16.78           91
# 1             107  371-7191       16.62          103
# 2             137  358-1921       10.30          104
# 3              84  375-9999        5.26           89
# 4              75  330-6626       12.61          121

# %%
desired_columns = ["Account Length", "VMail Message", "Day Calls"]
desired_columns
# Out:
# ['Account Length', 'VMail Message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %% [markdown]
# ### 1.2 Subconjunto de filas

# %%
data[1:25]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1     OH             107        415  371-7191         no        yes
# 2     NJ             137        415  358-1921         no         no
# 3     OH              84        408  375-9999        yes         no
# 4     OK              75        415  330-6626        yes         no
# 5     AL             118        510  391-8027        yes         no
# 6     MA             121        510  355-9993         no        yes
# 7     MO             147        415  329-9001        yes         no
# 8     LA             117        408  335-4719         no         no
# 9     WV             141        415  330-8173        yes        yes
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# 13    MT              95        510  394-8006         no         no
# ...

# %%
data[10:35]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 10    IN              65        415  329-6603         no         no
# 11    RI              74        415  344-9403         no         no
# 12    IA             168        408  363-1107         no         no
# 13    MT              95        510  394-8006         no         no
# 14    IA              62        415  366-9238         no         no
# 15    NY             161        415  351-7269         no         no
# 16    ID              85        408  350-8884         no        yes
# 17    VT              93        510  386-2923         no         no
# 18    VA              76        510  356-2992         no        yes
# 19    TX              73        415  373-2782         no         no
# 20    FL             147        415  396-5800         no         no
# 21    CO              77        408  393-7984         no         no
# 22    AZ             130        415  358-1958         no         no
# ...

# %%
data[:8] # CORRECCIÓN: es lo mismo que data[0:8]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# ...

# %%
data[3320:]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 3320    GA             122        510  411-5677        yes         no
# 3321    VT              60        415  400-2738         no         no
# 3322    MD              62        408  409-1856         no         no
# 3323    IN             117        415  362-5899         no         no
# 3324    WV             159        415  377-1164         no         no
# 3325    OH              78        408  368-8555         no         no
# 3326    OH              96        415  347-6812         no         no
# 3327    SC              79        415  348-3830         no         no
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# ...

# %% [markdown]
# ### 1.3 Subconjuntos de filas con condiciones booleanas

# %%
##Usuarios con Day Mins > 300
data[data["Day Mins"]>300].head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 76     DC              82        415  374-5353         no         no
# 156    OH              83        415  370-9116         no         no
# 197    TX             208        510  378-3625         no         no
# 230    MD              93        408  360-3324        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 76               0     300.3        109       51.05  ...        100
# 156              0     337.4        120       57.36  ...        116
# 197              0     326.5         67       55.51  ...        113
# 230              0     312.0        109       53.04  ...        100
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data[data["State"]=="NY"].head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 77     NY             144        408  360-1171         no         no
# 136    NY              75        415  374-8525         no        yes
# 182    NY              67        408  405-2888         no        yes
# 186    NY             106        408  422-1471         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 77               0      61.6        117       10.47  ...         85
# 136             21     175.8         97       29.89  ...        106
# 182             36     115.6        111       19.65  ...         94
# 186              0     158.7         74       26.98  ...        139
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data[(data["Day Mins"]>300) & (data["State"]=="NY")].head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 985    NY              64        415  345-9140        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 985              0     346.8         55       58.96  ...         79
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 15        27.01       160.6          128          7.23        5.4           9
# 985       21.21       275.4          102         12.39       13.3           9
#
#      Intl Charge  CustServ Calls  Churn?
# 15          1.46               4   True.
# 985         3.59               1   True.
#
# [2 rows x 21 columns]

# %%
data[(data["Day Mins"]>300) | (data["State"]=="NY")].head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 76     DC              82        415  374-5353         no         no
# 77     NY             144        408  360-1171         no         no
# 136    NY              75        415  374-8525         no        yes
# 156    OH              83        415  370-9116         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 76               0     300.3        109       51.05  ...        100
# 77               0      61.6        117       10.47  ...         85
# 136             21     175.8         97       29.89  ...        106
# 156              0     337.4        120       57.36  ...        116
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data[data["Day Calls"]<data["Night Calls"]].head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
# 5              0     223.4         98       37.98  ...        101       18.75
# 6             24     218.2         88       37.09  ...        108       29.62
# 7              0     157.0         79       26.69  ...         94        8.76
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
data[data["Day Mins"]<data["Night Mins"]].head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1    OH             107        415  371-7191         no        yes
# 4    OK              75        415  330-6626        yes         no
# 7    MO             147        415  329-9001        yes         no
# 8    LA             117        408  335-4719         no         no
# 9    WV             141        415  330-8173        yes        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 1             26     161.6        123       27.47  ...        103       16.62
# 4              0     166.7        113       28.34  ...        122       12.61
# 7              0     157.0         79       26.69  ...         94        8.76
# 8              0     184.5         97       31.37  ...         80       29.89
# 9             37     258.6         84       43.96  ...        111       18.87
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
##Minutos de día, de noche y Longitud de la Cuenta de los primeros 50 individuos
subset_first_50 = data[["Day Mins", "Night Mins", "Account Length"]][:50]
subset_first_50.head()
# Out:
#    Day Mins  Night Mins  Account Length
# 0     265.1       244.7             128
# 1     161.6       254.4             107
# 2     243.4       162.6             137
# 3     299.4       196.9              84
# 4     166.7       186.9              75

# %% [markdown]
# ### 1.4 Filtrado con loc e iloc

# %%
data.iloc[1:10, 3:6]
# Out:
#       Phone Int'l Plan VMail Plan
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %%
data.iloc[:,3:6] ##Todas las filas para las columnas entre la 3 y la 6
data.iloc[1:10,:] ##Todas las columnas para las filas de la 1 a la 10
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
# 7    MO             147        415  329-9001        yes         no
# 8    LA             117        408  335-4719         no         no
# 9    WV             141        415  330-8173        yes        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# ...

# %%
data.iloc[1:10, [2,5,7]]
# Out:
#    Area Code VMail Plan  Day Mins
# 1        415        yes     161.6
# 2        415         no     243.4
# 3        408         no     299.4
# 4        415         no     166.7
# 5        510         no     223.4
# 6        510        yes     218.2
# 7        415         no     157.0
# 8        408         no     184.5
# 9        415        yes     258.6

# %%
data.iloc[[1,5,8,36], [2,5,7]]
# Out:
#     Area Code VMail Plan  Day Mins
# 1         415        yes     161.6
# 5         510         no     223.4
# 8         408         no     184.5
# 36        408        yes     146.3

# %%
data.loc[[1,5,8,36], ["Area Code", "VMail Plan", "Day Mins"]]
# Out:
#     Area Code VMail Plan  Day Mins
# 1         415        yes     161.6
# 5         510         no     223.4
# 8         408         no     184.5
# 36        408        yes     146.3

# %% [markdown]
# ## 2 Añadir/eliminar columnas

# %% [markdown]
# ### 2.1 Añadir columnas

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
data["Total Mins"] = data["Day Mins"] + data["Night Mins"] + data["Eve Mins"]

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 0             25     265.1        110       45.07  ...       16.78
# 1             26     161.6        123       27.47  ...       16.62
# 2              0     243.4        114       41.38  ...       10.30
# 3              0     299.4         71       50.90  ...        5.26
# 4              0     166.7        113       28.34  ...       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# ...

# %% [markdown]
# ### 2.2 Eliminar columnas

# %%
data.drop(columns=["Day Mins", "Night Mins", "Eve Mins"])
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Calls  Day Charge  Eve Calls  Eve Charge  \
# ...

# %% [markdown]
# ### 2.3 Modificar columnas

# %%
data = data.rename(columns={'State': 'Estado', 'Phone': 'Teléfono'})

# %%
data.head()
# Out:
#   Estado  Account Length  Area Code  Teléfono Int'l Plan VMail Plan  \
# 0     KS             128        415  382-4657         no        yes
# 1     OH             107        415  371-7191         no        yes
# 2     NJ             137        415  358-1921         no         no
# 3     OH              84        408  375-9999        yes         no
# 4     OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 0             25     265.1        110       45.07  ...       16.78
# 1             26     161.6        123       27.47  ...       16.62
# 2              0     243.4        114       41.38  ...       10.30
# 3              0     299.4         71       50.90  ...        5.26
# 4              0     166.7        113       28.34  ...       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
data.shape
# Out:
# (3333, 22)

# %%
data = data[['Estado', 'Teléfono', 'Day Mins']]

# %%
data
# Out:
#      Estado  Teléfono  Day Mins
# 0        KS  382-4657     265.1
# 1        OH  371-7191     161.6
# 2        NJ  358-1921     243.4
# 3        OH  375-9999     299.4
# 4        OK  330-6626     166.7
# ...     ...       ...       ...
# 3328     AZ  414-4276     156.2
# 3329     WV  370-3271     231.1
# 3330     RI  328-8230     180.8
# 3331     CT  364-6381     213.8
# 3332     TN  400-4344     234.4
#
# [3333 rows x 3 columns]

# %%
data.columns = ['Región', 'Teléfono', 'Mínimo del día']

# %%
data
# Out:
#      Región  Teléfono  Mínimo del día
# 0        KS  382-4657           265.1
# 1        OH  371-7191           161.6
# 2        NJ  358-1921           243.4
# 3        OH  375-9999           299.4
# 4        OK  330-6626           166.7
# ...     ...       ...             ...
# 3328     AZ  414-4276           156.2
# 3329     WV  370-3271           231.1
# 3330     RI  328-8230           180.8
# 3331     CT  364-6381           213.8
# 3332     TN  400-4344           234.4
#
# [3333 rows x 3 columns]
