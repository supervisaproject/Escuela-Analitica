# %% [markdown]
# ## Tratamiento de DataFrame mediante consultas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandasql
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26817 sha256=4b3d7610df949271c7226fb5d3d89e8ca1b3ce05c229d9f86684f25f4f3671a3
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 103 kB 3.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importamos módulos

# %%
import pandas as pd
import pandasql as ps

# %%
cd ..
# Out:
# /home/jovyan/Bloque 3/Sesion 2

# %% [markdown]
# ## Traramiento datos de clientes

# %%
customer = pd.read_csv("DataSet/Customer Churn Model.txt")

# %%
customer.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
ps.sqldf("""SELECT STATE, Phone FROM customer """, locals())
# Out:
#      State     Phone
# 0       KS  382-4657
# 1       OH  371-7191
# 2       NJ  358-1921
# 3       OH  375-9999
# 4       OK  330-6626
# ...    ...       ...
# 3328    AZ  414-4276
# 3329    WV  370-3271
# 3330    RI  328-8230
# 3331    CT  364-6381
# 3332    TN  400-4344
#
# [3333 rows x 2 columns]

# %%
new_df = ps.sqldf("""SELECT * FROM customer WHERE [Day Charge] < 30""", locals())

# %%
new_df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    OH             107        415  371-7191         no        yes
# 1    OK              75        415  330-6626        yes         no
# 2    MO             147        415  329-9001        yes         no
# 3    IN              65        415  329-6603         no         no
# 4    IA             168        408  363-1107         no         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             26     161.6        123       27.47  ...        103       16.62
# 1              0     166.7        113       28.34  ...        122       12.61
# 2              0     157.0         79       26.69  ...         94        8.76
# 3              0     129.1        137       21.95  ...         83       19.42
# 4              0     128.8         96       21.90  ...         71        8.92
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
new_df_2 = ps.sqldf("""SELECT * FROM customer WHERE [Day Charge] < 30 AND [Night Charge] > 15""", locals())

# %%
new_df_2
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    WI              85        408  381-5878        yes         no
# 1    CA              75        510  350-1422         no        yes
# 2    MO              86        415  385-3111         no         no
# 3    NE              89        415  420-6414         no        yes
# 4    AR             153        408  339-3636         no         no
# 5    VA             172        510  408-2089         no         no
# 6    GA              73        408  385-6952         no         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0              0     165.4        107       28.12  ...        126       16.66
# 1             38     163.6        132       27.81  ...        113       12.47
# 2              0      83.5         96       14.20  ...         63       18.79
# 3             29     163.5         80       27.80  ...        136       23.36
# ...

# %% [markdown]
# ## Tratamiento datos de atletas

# %%
score_df = pd.read_csv("DataSet/athlete_score.csv")

# %%
score_df.head()
# Out:
#    Unnamed: 0         Athlete     score
# 0           0   Aleksey Nemov  0.647714
# 1           1   Alicia Coutts  0.301431
# 2           2  Missy Franklin  0.721520
# 3           3   Nastia Liukin  0.038814
# 4           4        Sun Yang  0.024936

# %%
country_df = pd.read_excel("DataSet/atletas_country.xlsx")

# %%
country_df.head()
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
join_df = ps.sqldf("""SELECT * FROM score_df INNER JOIN country_df ON score_df.Athlete=country_df.Athlete""", locals())

# %%
join_df
# Out:
#       Unnamed: 0            Athlete     score            Athlete  \
# 0              0      Aleksey Nemov  0.647714      Aleksey Nemov
# 1              1      Alicia Coutts  0.301431      Alicia Coutts
# 2              2     Missy Franklin  0.721520     Missy Franklin
# 3              3      Nastia Liukin  0.038814      Nastia Liukin
# 4              4           Sun Yang  0.024936           Sun Yang
# ...          ...                ...       ...                ...
# 2295        2295       Gábor Balogh  0.724633       Gábor Balogh
# 2296        2296         Steph Cook  0.360079         Steph Cook
# 2297        2297       Emily deRiel  0.069141       Emily deRiel
# 2298        2298       Pavel Dovgal  0.176767       Pavel Dovgal
# 2299        2299  Dmitry Svatkovsky  0.424095  Dmitry Svatkovsky
#
#             Country
# 0            Russia
# 1         Australia
# 2     United States
# 3     United States
# 4             China
# ...             ...
# 2295        Hungary
# ...
