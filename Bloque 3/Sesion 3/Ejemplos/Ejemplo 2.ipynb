# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.1 MB 2.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 20.1 MB 38.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 34.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Conectarnos a una API que no requiere parámetros

# %%
import json

# %%
import pandas as pd

# %%
import requests

# %%
response = requests.get("http://api.open-notify.org/this-api-doesnt-exist")

# %%
response
# Out:
# <Response [404]>

# %%
response = requests.get("https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/all.json")
print(response.status_code)
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 1,
#   'name': 'A-Bomb',
#   'slug': '1-a-bomb',
#   'powerstats': {'intelligence': 38,
#    'strength': 100,
#    'speed': 17,
#    'durability': 80,
#    'power': 24,
#    'combat': 64},
#   'appearance': {'gender': 'Male',
#    'race': 'Human',
#    'height': ["6'8", '203 cm'],
#    'weight': ['980 lb', '441 kg'],
#    'eyeColor': 'Yellow',
#    'hairColor': 'No Hair'},
#   'biography': {'fullName': 'Richard Milhouse Jones',
#    'alterEgos': 'No alter egos found.',
#    'aliases': ['Rick Jones'],
#    'placeOfBirth': 'Scarsdale, Arizona',
#    'firstAppearance': 'Hulk Vol 2 #2 (April, 2008) (as A-Bomb)',
#    'publisher': 'Marvel Comics',
#    'alignment': 'good'},
#   'work': {'occupation': 'Musician, adventurer, author; formerly talk show host',
#    'base': '-'},
#   'connections': {'groupAffiliation': 'Hulk Family; Excelsior (sponsor), Avengers (honorary member); formerly partner of the Hulk, Captain America and Captain Marvel; Teen Brigade; ally of Rom',
# ...

# %%
pd.DataFrame(response.json()).head()
# Out:
#    id         name           slug  \
# 0   1       A-Bomb       1-a-bomb
# 1   2   Abe Sapien   2-abe-sapien
# 2   3     Abin Sur     3-abin-sur
# 3   4  Abomination  4-abomination
# 4   5      Abraxas      5-abraxas
#
#                                           powerstats  \
# 0  {'intelligence': 38, 'strength': 100, 'speed':...
# 1  {'intelligence': 88, 'strength': 28, 'speed': ...
# 2  {'intelligence': 50, 'strength': 90, 'speed': ...
# 3  {'intelligence': 63, 'strength': 80, 'speed': ...
# 4  {'intelligence': 88, 'strength': 63, 'speed': ...
#
#                                           appearance  \
# 0  {'gender': 'Male', 'race': 'Human', 'height': ...
# 1  {'gender': 'Male', 'race': 'Icthyo Sapien', 'h...
# 2  {'gender': 'Male', 'race': 'Ungaran', 'height'...
# 3  {'gender': 'Male', 'race': 'Human / Radiation'...
# 4  {'gender': 'Male', 'race': 'Cosmic Entity', 'h...
#
#                                            biography  \
# ...

# %% [markdown]
# ### Extraemos los datos de forma individual

# %%
pd.DataFrame(response.json())["id"][0]
# Out:
# 1

# %%
pd.DataFrame(response.json())["name"][0]
# Out:
# 'A-Bomb'

# %%
pd.DataFrame(response.json())["slug"][0]
# Out:
# '1-a-bomb'

# %%
pd.DataFrame(response.json())["powerstats"][0]
# Out:
# {'intelligence': 38,
#  'strength': 100,
#  'speed': 17,
#  'durability': 80,
#  'power': 24,
#  'combat': 64}

# %%
pd.DataFrame(response.json())["appearance"][0]
# Out:
# {'gender': 'Male',
#  'race': 'Human',
#  'height': ["6'8", '203 cm'],
#  'weight': ['980 lb', '441 kg'],
#  'eyeColor': 'Yellow',
#  'hairColor': 'No Hair'}

# %%
pd.DataFrame(response.json())["work"][0]
# Out:
# {'occupation': 'Musician, adventurer, author; formerly talk show host',
#  'base': '-'}

# %%
pd.DataFrame(response.json())["connections"][0]
# Out:
# {'groupAffiliation': 'Hulk Family; Excelsior (sponsor), Avengers (honorary member); formerly partner of the Hulk, Captain America and Captain Marvel; Teen Brigade; ally of Rom',
#  'relatives': 'Marlo Chandler-Jones (wife); Polly (aunt); Mrs. Chandler (mother-in-law); Keith Chandler, Ray Chandler, three unidentified others (brothers-in-law); unidentified father (deceased); Jackie Shorr (alleged mother; unconfirmed)'}

# %%
pd.DataFrame(response.json())["images"][0]
# Out:
# {'xs': 'https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/images/xs/1-a-bomb.jpg',
#  'sm': 'https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/images/sm/1-a-bomb.jpg',
#  'md': 'https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/images/md/1-a-bomb.jpg',
#  'lg': 'https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/images/lg/1-a-bomb.jpg'}

# %%
imagenes_a_bomb = pd.DataFrame(response.json())["images"][0]

# %%
pd.DataFrame(imagenes_a_bomb, index = [0])["md"][0]
# Out:
# 'https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/images/md/1-a-bomb.jpg'

# %%
filename=pd.DataFrame(imagenes_a_bomb, index = [0])['md'][0]

# %%
from IPython.display import Image
Image(pd.DataFrame(imagenes_a_bomb, index = [0])['md'][0])

# %%
response_powerstats = requests.get("https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/powerstats/1.json")
response_appearance = requests.get("https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/appearance/1.json")
response_biography = requests.get("https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/biography/1.json")
response_connections = requests.get("https://cdn.rawgit.com/akabab/superhero-api/0.2.0/api/connections/1.json")

# %%
response_powerstats.json()
# Out:
# {'intelligence': 38,
#  'strength': 100,
#  'speed': 17,
#  'durability': 80,
#  'power': 24,
#  'combat': 64}

# %%
pd.DataFrame(response_powerstats.json(), index = [0])
# Out:
#    intelligence  strength  speed  durability  power  combat
# 0            38       100     17          80     24      64

# %%
response_appearance.json()
# Out:
# {'gender': 'Male',
#  'race': 'Human',
#  'height': ["6'8", '203 cm'],
#  'weight': ['980 lb', '441 kg'],
#  'eyeColor': 'Yellow',
#  'hairColor': 'No Hair'}

# %%
pd.DataFrame(response_appearance.json(), index = [0, 1])
# Out:
#   gender   race  height  weight eyeColor hairColor
# 0   Male  Human     6'8  980 lb   Yellow   No Hair
# 1   Male  Human  203 cm  441 kg   Yellow   No Hair

# %%
response_biography.json()
# Out:
# {'fullName': 'Richard Milhouse Jones',
#  'alterEgos': 'No alter egos found.',
#  'aliases': ['Rick Jones'],
#  'placeOfBirth': 'Scarsdale, Arizona',
#  'firstAppearance': 'Hulk Vol 2 #2 (April, 2008) (as A-Bomb)',
#  'publisher': 'Marvel Comics',
#  'alignment': 'good'}

# %%
pd.DataFrame(response_biography.json(), index = [0])
# Out:
#                  fullName             alterEgos     aliases  \
# 0  Richard Milhouse Jones  No alter egos found.  Rick Jones
#
#          placeOfBirth                          firstAppearance      publisher  \
# 0  Scarsdale, Arizona  Hulk Vol 2 #2 (April, 2008) (as A-Bomb)  Marvel Comics
#
#   alignment
# 0      good

# %%
response_connections.json()
# Out:
# {'groupAffiliation': 'Hulk Family; Excelsior (sponsor), Avengers (honorary member); formerly partner of the Hulk, Captain America and Captain Marvel; Teen Brigade; ally of Rom',
#  'relatives': 'Marlo Chandler-Jones (wife); Polly (aunt); Mrs. Chandler (mother-in-law); Keith Chandler, Ray Chandler, three unidentified others (brothers-in-law); unidentified father (deceased); Jackie Shorr (alleged mother; unconfirmed)'}

# %% [markdown]
# ### Extraemos los datos en un sólo DataFrame

# %%
all_data = pd.json_normalize(response.json())

# %%
all_data.head()
# Out:
#    id         name           slug  powerstats.intelligence  \
# 0   1       A-Bomb       1-a-bomb                       38
# 1   2   Abe Sapien   2-abe-sapien                       88
# 2   3     Abin Sur     3-abin-sur                       50
# 3   4  Abomination  4-abomination                       63
# 4   5      Abraxas      5-abraxas                       88
#
#    powerstats.strength  powerstats.speed  powerstats.durability  \
# 0                  100                17                     80
# 1                   28                35                     65
# 2                   90                53                     64
# 3                   80                53                     90
# 4                   63                83                    100
#
#    powerstats.power  powerstats.combat appearance.gender  ...  \
# 0                24                 64              Male  ...
# 1               100                 85              Male  ...
# ...

# %% [markdown]
# ## Conectarnos a una API que  requiere parámetros

# %%
response_all = requests.get("http://api.open-notify.org/iss-pass.json")

# %%
response_all.json()
# Out:
# {'message': 'failure', 'reason': 'Latitude must be specified'}

# %%
parameters = {
    "lat": 40.71,
    "lon": -74
}

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# %% [markdown]
# ### Extraemos los datos de forma individual

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1583752474,
#   'latitude': 40.71,
#   'longitude': -74.0,
#   'passes': 5},
#  'response': [{'duration': 589, 'risetime': 1583755675},
#   {'duration': 590, 'risetime': 1583810057},
#   {'duration': 647, 'risetime': 1583815822},
#   {'duration': 581, 'risetime': 1583821699},
#   {'duration': 569, 'risetime': 1583827576}]}

# %%
response.json()['response']
# Out:
# [{'duration': 564, 'risetime': 1582891188},
#  {'duration': 625, 'risetime': 1582897019},
#  {'duration': 650, 'risetime': 1582902825},
#  {'duration': 405, 'risetime': 1582908713}]

# %%
data = response.json()['request']

# %%
data
# Out:
# {'altitude': 100,
#  'datetime': 1582879789,
#  'latitude': 40.71,
#  'longitude': -74.0,
#  'passes': 5}

# %%
data['altitude']
# Out:
# 100

# %% [markdown]
# ### Extraemos los datos en un sólo DataFrame

# %%
pd.json_normalize(response.json())
# Out:
#    message                                           response  \
# 0  success  [{'duration': 589, 'risetime': 1583755675}, {'...
#
#    request.altitude  request.datetime  request.latitude  request.longitude  \
# 0               100        1583752474             40.71              -74.0
#
#    request.passes
# 0               5

# %%
pd.json_normalize(response.json())
# Out:
#    message                                           response  \
# 0  success  [{'duration': 589, 'risetime': 1583755675}, {'...
#
#    request.altitude  request.datetime  request.latitude  request.longitude  \
# 0               100        1583752474             40.71              -74.0
#
#    request.passes
# 0               5

# %%
pd.json_normalize(response.json(), 'response', ['message', 'request'], errors='ignore')
# Out:
#    duration    risetime  message  \
# 0       589  1583755675  success
# 1       590  1583810057  success
# 2       647  1583815822  success
# 3       581  1583821699  success
# 4       569  1583827576  success
#
#                                              request
# 0  {'altitude': 100, 'datetime': 1583752474, 'lat...
# 1  {'altitude': 100, 'datetime': 1583752474, 'lat...
# 2  {'altitude': 100, 'datetime': 1583752474, 'lat...
# 3  {'altitude': 100, 'datetime': 1583752474, 'lat...
# 4  {'altitude': 100, 'datetime': 1583752474, 'lat...

# %%
pd.DataFrame(pd.json_normalize(response.json(), 'response', ['message', 'request'], errors='ignore')['request'][0], index = [0])
# Out:
#    altitude    datetime  latitude  longitude  passes
# 0       100  1583752474     40.71      -74.0       5
